# %%
import pandas as pd

# %%
df =  pd.read_csv('./dados.csv', sep=';')
df
# Out:
#      Unnamed: 0  papel   tipo             empresa  \
# 0             0  AALR3  ON NM        ALLIAR ON NM
# 1             1  ABCB4  PN N2    ABC Brasil PN N2
# 2             2  ABEV3     ON        AMBEV S/A ON
# 3             3  ADHM3     ON      ADVANCED-DH ON
# 4             4  AERI3  ON NM         AERIS ON NM
# ..          ...    ...    ...                 ...
# 465         465  VVEO3  ON NM         VIVEO ON NM
# 466         466  ONCO3  ON NM  ONCOCLINICAS ON NM
# 467         467  KRSA3  ON NM    KORA SAUDE ON NM
# 468         468  VITT3  ON NM        VITTIA ON NM
# 469         469  VBBR3     ON            VIBRA ON
#
#                                         setor cotacao dt_ult_cotacao  \
# 0    Serv.Méd.Hospit. Análises e Diagnósticos   18,65     26/11/2021
# 1                  Intermediários Financeiros   16,15     26/11/2021
# 2                                     Bebidas   16,69     26/11/2021
# 3                                         NaN    1,56     28/12/2020
# ...
